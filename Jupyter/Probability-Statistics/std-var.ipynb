# %% [markdown]
# # 方差

# %%
import numpy as np
x_1 = np.array([55, 45, 60, 40])
x_2 = np.array([51, 49, 52, 48])

print(np.var(x_1))
print(np.var(x_2))
# Out:
# 62.5
# 2.5

# %%
import matplotlib.pyplot as plt
plt.scatter(x_1, x_2)
